# %%
import pandas as pd

# %%
df = pd.read_excel("data/202412_202412_연령별인구현황_연간.xlsx", skiprows=3, usecols='B,C,E:O')
df
# Out:
# c:\python3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#          행정기관       총 인구수       0~9세     10~19세     20~29세     30~39세  \
# 0        전국    51,217,221  3,140,118  4,619,265  5,955,656  6,624,563
# 1     서울특별시     9,331,828    483,780    720,767  1,308,260  1,442,665
# 2     부산광역시     3,266,598    181,736    262,852    358,388    388,958
# 3     대구광역시     2,363,629    142,228    212,438    268,100    282,632
# 4     인천광역시     3,021,010    195,196    272,576    351,396    422,100
# 5     광주광역시     1,408,422     92,837    145,418    182,033    173,762
# 6     대전광역시     1,439,157     91,513    135,613    193,470    190,937
# 7     울산광역시     1,098,049     73,097    109,370    117,157    136,293
# 8   세종특별자치시       390,685     41,351     52,539     37,080     58,822
# ...

# %%
import pandas as pd
data = {
    '이름':['홍길동','유관순','이순신','강감찬','김구','김유신','홍길자','홍길순'],
    '학교':['가산고','가산고','가산고','가산고','가산고','디지털고','디지털고','디지털고'],
    '키':[197,184,168,187,188,202,188,190],
    '국어':[90,40,80,40,15,80,55,100],
    '영어':[85,35,75,60,20,100,65,85],
    '수학':[100,50,70,70,10,95,45,90],
    '과학':[95,55,80,75,35,85,40,95],
    '사회':[85,25,75,80,10,80,35,95],
    'SW특기':['Python','Java','Javascript','','','C','PYTHON','C#']
}

# index 추가해서 DataFrame 구서
df = pd.DataFrame(data, index=['1번','2번','3번','4번','5번','6번','7번','8번'])
df.index.name="지원번호"
df
# Out:
#        이름    학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    홍길동   가산고  197   90   85  100  95  85      Python
# 2번    유관순   가산고  184   40   35   50  55  25        Java
# 3번    이순신   가산고  168   80   75   70  80  75  Javascript
# 4번    강감찬   가산고  187   40   60   70  75  80
# 5번     김구   가산고  188   15   20   10  35  10
# 6번    김유신  디지털고  202   80  100   95  85  80           C
# 7번    홍길자  디지털고  188   55   65   45  40  35      PYTHON
# 8번    홍길순  디지털고  190  100   85   90  95  95          C#

# %%
## 컬럼 출력하기

df['이름']
df['키']

#df.columns의 index를 가지고 출력
df.columns
df.columns[0]
df[df.columns[0]] # df['이름']

# 컬럼 2개 이상 출력 : 대괄호 2번 사용
df[['이름','키']]
df.columns
df[['이름','학교','SW특기']]
df[['학교','키','국어','영어','수학']]
df.columns
df[df.columns[1:6]] # df.columns를 사용해서 슬라이싱 가능
df[df.columns[:-1]] # 제일 뒤 삭제후 모든 컬럼 출력
df[df.columns[[1,3,4]]] # 컬럼 부분을 출력

# df[1:5] 컬럼 전체의 row 값을 출력

df[df.columns[5:]][1:3]
# Out:
#       수학  과학  사회        SW특기
# 지원번호
# 2번    50  55  25        Java
# 3번    70  80  75  Javascript
