# %%
import pandas as pd
data = {
    '이름':['홍길동','유관순','이순신','강감찬','김구','김유신','홍길자','홍길순'],
    '학교':['가산고','가산고','가산고','가산고','가산고','디지털고','디지털고','디지털고'],
    '키':[197,184,168,187,188,202,188,190],
    '국어':[90,40,80,40,15,80,55,100],
    '영어':[85,35,75,60,20,100,65,85],
    '수학':[100,50,70,70,10,95,45,90],
    '과학':[95,55,80,75,35,85,40,95],
    '사회':[85,25,75,80,10,80,35,95],
    'SW특기':['Python','Java','Javascript','','','C','PYTHON','C#']
}

# index 추가해서 DataFrame 구서
df = pd.DataFrame(data, index=['1번','2번','3번','4번','5번','6번','7번','8번'])
df.index.name="지원번호"
df
# Out:
#        이름    학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    홍길동   가산고  197   90   85  100  95  85      Python
# 2번    유관순   가산고  184   40   35   50  55  25        Java
# 3번    이순신   가산고  168   80   75   70  80  75  Javascript
# 4번    강감찬   가산고  187   40   60   70  75  80
# 5번     김구   가산고  188   15   20   10  35  10
# 6번    김유신  디지털고  202   80  100   95  85  80           C
# 7번    홍길자  디지털고  188   55   65   45  40  35      PYTHON
# 8번    홍길순  디지털고  190  100   85   90  95  95          C#

# %%
### csv 파일 저장하는 방법 utf-8 : 워드패드, vscode에서 읽기 가능,
### utf-8-sig : excel 파일에서도 한글 지원 가능
# df.to_csv('score.csv',encoding='utf-8')

### txt 파일 저장하는 방법 , 기본, 쉼표 사용, sep 옵션 구분자 변경이 가능
df.to_csv('data/score.txt', encoding='utf-8')
df.to_csv('data/score.txt', sep='\t', encoding='utf-8')

### exsel 파일 저장하는 방법
df.to_excel('data/score.xlsx')

# %%
### csv 파일 읽어오기, index 지정 가능 : index_col
# df = pd.read_csv('score.csv', index_col='지원번호')

### txt 파일 읽어오기, sep 구분자는 기본 쉼표를 기준으로 DataFrame 형태로 변경
# 지정된 것이 다르면 데이터 읽어오기가 제대로 안됨.
# df = pd.read_csv('data/score.txt', sep='\t',index_col='지원번호')
# df = pd.read_csv('data/score.txt', sep='\t')
# df.set_index('지원번호', inplace=True)

### excel 파일 읽어오기
# df = pd.read_excel('data/score.xlsx')
# df

### excel 파일 읽어오기
# df = pd.read_excel('data/score.xlsx', index_col='지원번호')
# df

# %%
df = pd.read_excel('data/202412_202412_주민등록인구및세대현황_월간.xlsx')
df
# Out:
# c:\python3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#    ※ 매월 말일자 통계 현황 Unnamed: 1  Unnamed: 2  Unnamed: 3      Unnamed: 4  \
# 0             NaN        NaN    2024년12월         NaN             NaN
# 1          행정기관코드       행정기관        총인구수         세대수          세대당 인구
# 2      1000000000       전국    51,217,221  24,118,928            2.12
# 3      1100000000    서울특별시     9,331,828   4,482,063            2.08
# 4      2600000000    부산광역시     3,266,598   1,570,403            2.08
# 5      2700000000    대구광역시     2,363,629   1,104,130            2.14
# 6      2800000000    인천광역시     3,021,010   1,373,827            2.20
# 7      2900000000    광주광역시     1,408,422     658,075            2.14
# 8      3000000000    대전광역시     1,439,157     687,757            2.09
# 9      3100000000    울산광역시     1,098,049     495,378            2.22
# ...

# %%
# skiprows : 상ㄷ단 row개수를 삭제후 ㄱ가져오기

df = pd.read_excel('data/202412_202412_주민등록인구및세대현황_월간.xlsx', skiprows=2,index_col='행정기관', usecols='B,E:H', nrows=1)
df
# Out:
# c:\python3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#       세대당 인구      남자 인구수      여자 인구수  남여 비율
# 행정기관
# 전국      2.12  25,498,324  25,718,897   0.99
