# %%
import pandas as pd
data = {
    '이름':['홍길동','유관순','이순신','강감찬','김구','김유신','홍길자','홍길순'],
    '학교':['가산고','가산고','가산고','가산고','가산고','디지털고','디지털고','디지털고'],
    '키':[197,184,168,187,188,202,188,190],
    '국어':[90,40,80,40,15,80,55,100],
    '영어':[85,35,75,60,20,100,65,85],
    '수학':[100,50,70,70,10,95,45,90],
    '과학':[95,55,80,75,35,85,40,95],
    '사회':[85,25,75,80,10,80,35,95],
    'SW특기':['Python','Java','Javascript','','','C','PYTHON','C#']
}

df = pd.DataFrame(data, index=['1번','2번','3번','4번','5번','6번','7번','8번'])
df.index.name="지원번호"
df
# Out:
#        이름    학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    홍길동   가산고  197   90   85  100  95  85      Python
# 2번    유관순   가산고  184   40   35   50  55  25        Java
# 3번    이순신   가산고  168   80   75   70  80  75  Javascript
# 4번    강감찬   가산고  187   40   60   70  75  80
# 5번     김구   가산고  188   15   20   10  35  10
# 6번    김유신  디지털고  202   80  100   95  85  80           C
# 7번    홍길자  디지털고  188   55   65   45  40  35      PYTHON
# 8번    홍길순  디지털고  190  100   85   90  95  95          C#

# %%
# df = pd.read_excel('file/score.xlsx')
# df.set_index("지원번호",inplace=True) # 지원번호컬럼 index 지정
df = pd.read_excel('file/score.xlsx', index_col="지원번호") # index 지정하면서 호출
df
# Out:
#        이름    학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# 1번    홍길동   가산고  197   90   85  100  95  85      Python
# 2번    유관순   가산고  184   40   35   50  55  25        Java
# 3번    이순신   가산고  168   80   75   70  80  75  Javascript
# 4번    강감찬   가산고  187   40   60   70  75  80         NaN
# 5번     김구   가산고  188   15   20   10  35  10         NaN
# 6번    김유신  디지털고  202   80  100   95  85  80           C
# 7번    홍길자  디지털고  188   55   65   45  40  35      PYTHON
# 8번    홍길순  디지털고  190  100   85   90  95  95          C#

# %%
df = pd.read_csv('file/stock.csv', index_col="N")
df.index.name = "번호"
df.head() # 상위 5개 출력
df.head(20) # 숫자만큼출력
df.tail() # 하위 5개 추력
df.tail(20)
# Out:
#                          종목명        현재가      전일비     등락률    액면가    시가총액  \
# 번호
# 231                    경동나비엔     76,600    하락100  -0.13%  1,000  11,160
# 232               KODEX 삼성그룹      8,155     상승25  +0.31%      0  11,050
# 233                    롯데웰푸드    116,800  상승2,000  +1.74%    500  11,020
# 234                      종근당     78,800    상승100  +0.13%  2,500  10,877
# 235                    두산퓨얼셀     16,380    상승370  +2.31%    100  10,728
# 236         RISE CD금리액티브(합성)    103,790      보합0   0.00%      0  10,712
# 237                     롯데리츠      3,630     상승30  +0.83%    500  10,490
# 238                     다우기술     23,300    상승650  +2.87%    500  10,454
# 239                  LX인터내셔널     26,950    상승100  +0.37%  5,000  10,446
# 240                     가온전선     63,000    하락900  -1.41%  5,000  10,422
# 241                     한국카본     19,980  하락1,070  -5.08%    500  10,371
# 242                  LS에코에너지     33,700    상승550  +1.66%    500  10,321
# ...

# %%
# 개수 평균 표준편차 최소값 25% 50% 75% 최대값
df.describe()
# Out:
#            외국인비율         ROE
# count  250.00000  202.000000
# mean    18.42600    8.374010
# std     16.25217   13.127001
# min      0.00000  -53.210000
# 25%      6.52000    3.025000
# 50%     14.14500    8.085000
# 75%     28.26250   13.147500
# max     75.18000   58.010000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 250 entries, 1 to 250
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   종목명     250 non-null    object
#  1   현재가     250 non-null    object
#  2   전일비     250 non-null    object
#  3   등락률     250 non-null    object
#  4   액면가     250 non-null    object
#  5   시가총액    250 non-null    object
#  6   상장주식수   250 non-null    object
#  7   외국인비율   250 non-null    float64
#  8   거래량     250 non-null    object
#  9   PER     207 non-null    object
#  10  ROE     202 non-null    float64
# dtypes: float64(2), object(9)
# memory usage: 23.4+ KB

# %%
df.describe()
# Out:
#            외국인비율         ROE
# count  250.00000  202.000000
# mean    18.42600    8.374010
# std     16.25217   13.127001
# min      0.00000  -53.210000
# 25%      6.52000    3.025000
# 50%     14.14500    8.085000
# 75%     28.26250   13.147500
# max     75.18000   58.010000

# %%
# df = pd.read_csv('file/stock.csv')
# df.info() # 컬럼의 타입 확인
# df.values # 배열구조로 출력
# df.index
# for i in df.index:
#     print(df.loc[i])
df.columns # 컬럼명 출력
# for i in df.columns:
#     print(i)
df.shape # row, columns 수를 보여줌. 배열크기 확인
df.shape[0]
df.shape[1]
df.shape
# Out:
# (8, 9)

# %%
df = pd.read_excel('file/score.xlsx', index_col='지원번호')
# df['이름']
df['키']
df['국어'] # 컬럼 1개 출력
df[['키','국어']] # 컬럼 2개 이상 출력시 [[]] 사용

df['키'].min()
df['키'].max()

df['키'].count()
df['키'].describe() # count, mean, std, min, max

df.describe()
df['키'].nlargest()
# Out:
# 지원번호
# 6번    202
# 1번    197
# 8번    190
# 5번    188
# 7번    188
# Name: 키, dtype: int64

# %%
df['키'].sum()
df['키'].mean() # 평균 타입 # float 타입
df['학교'].unique() # 중복제거 리스트 보여줌. 리스트타입

# for i in df['학교'].unique():
#     print(i)
    
df['학교'].nunique()
# Out:
# 2
